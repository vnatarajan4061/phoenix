# %%
import json
import logging
import os
import time
from datetime import datetime, timedelta

import pandas as pd
import requests

# %%
# Setup logging
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# MLB Stats API base URL
BASE_URL = "https://statsapi.mlb.com/api"


class MLBStatsAPI:
    def __init__(self, rate_limit_pause=1):
        self.rate_limit_pause = rate_limit_pause  # Time to wait between API calls

    def make_request(self, endpoint, params=None, max_retries=3):
        """Make API request with retries"""
        url = f"{BASE_URL}/{endpoint}"
        for attempt in range(max_retries):
            try:
                response = requests.get(url, params=params)
                response.raise_for_status()
                time.sleep(self.rate_limit_pause)  # Prevent rate limiting
                return response.json()
            except Exception as e:
                logger.warning(
                    f"API request failed: {e}. Attempt {attempt + 1}/{max_retries}"
                )
                if attempt == max_retries - 1:
                    raise
                time.sleep(2)  # Wait before retry

    def get_schedule(self, start_date, end_date):
        """Get MLB schedule for a date range"""
        endpoint = "v1/schedule"
        params = {
            "startDate": start_date,
            "endDate": end_date,
            "sportId": 1,  # MLB
            "gameType": "R",  # Regular season games
            "hydrate": "venue,team",
        }
        return self.make_request(endpoint, params)

    def get_game_data(self, game_pk):
        """Get detailed game data"""
        endpoint = f"v1.1/game/{game_pk}/feed/live"
        params = {"hydrate": "boxscore,weather"}
        return self.make_request(endpoint, params)

    def get_player_stats(self, player_id, season, end_date=None):
        """Get player stats for a season optionally up to a date"""
        endpoint = f"v1/people/{player_id}/stats"

        # Basic stats
        params = {
            "stats": "season",
            "season": season,
            "group": "hitting,pitching",
            "gameType": "R",
        }

        # Add date range if provided
        if end_date:
            params["stats"] = "byDateRange"
            params["startDate"] = f"{season}-03-01"
            params["endDate"] = end_date

        regular_stats = self.make_request(endpoint, params)

        # Advanced stats
        params["stats"] = "sabermetrics"
        advanced_stats = self.make_request(endpoint, params)

        return {"regular": regular_stats, "advanced": advanced_stats}

    def get_matchup_stats(self, batter_id, pitcher_id, season):
        """Get batter vs pitcher matchup stats"""
        endpoint = f"v1/people/{batter_id}/stats/vsPlayer"
        params = {"stats": "vsPlayer", "season": season, "opposingPlayerId": pitcher_id}
        return self.make_request(endpoint, params)


def collect_mlb_data(start_date, end_date, output_dir="mlb_data"):
    """Main function to collect MLB data"""
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)

    # Initialize API client
    api = MLBStatsAPI()
    season = start_date.split("-")[0]  # Extract season year

    # Get schedule
    logger.info(f"Getting MLB schedule from {start_date} to {end_date}")
    schedule = api.get_schedule(start_date, end_date)

    # Data storage
    games_data = []
    batter_stats = []
    pitcher_stats = []
    weather_data = []

    # Process each game date
    for date_info in schedule.get("dates", []):
        game_date = date_info["date"]
        logger.info(f"Processing games for {game_date}")

        # Process each game
        for game in date_info.get("games", []):
            game_pk = game["gamePk"]

            # Skip games that haven't been played yet
            if game["status"]["abstractGameState"] != "Final":
                logger.info(f"Skipping game {game_pk} - not completed")
                continue

            logger.info(f"Processing game {game_pk}")

            try:
                # Get detailed game data
                game_detail = api.get_game_data(game_pk)

                # Extract weather information
                weather = game_detail.get("gameData", {}).get("weather", {})
                weather_data.append(
                    {
                        "game_pk": game_pk,
                        "game_date": game_date,
                        "temperature": weather.get("temp"),
                        "condition": weather.get("condition"),
                        "wind": weather.get("wind"),
                    }
                )

                # Get box score data
                boxscore = game_detail.get("liveData", {}).get("boxscore", {})

                # Team information
                away_team = game["teams"]["away"]["team"]
                home_team = game["teams"]["home"]["team"]

                # Find starting pitchers
                away_starter = None
                home_starter = None

                for player_id, player in (
                    boxscore.get("teams", {}).get("away", {}).get("players", {}).items()
                ):
                    if (
                        player.get("stats", {})
                        .get("pitching", {})
                        .get("gamesStarted", 0)
                        > 0
                    ):
                        away_starter = player
                        break

                for player_id, player in (
                    boxscore.get("teams", {}).get("home", {}).get("players", {}).items()
                ):
                    if (
                        player.get("stats", {})
                        .get("pitching", {})
                        .get("gamesStarted", 0)
                        > 0
                    ):
                        home_starter = player
                        break

                # Process batters for both teams
                for (
                    team_side,
                    opponent_side,
                    team_info,
                    opponent_info,
                    opponent_starter,
                ) in [
                    ("away", "home", away_team, home_team, home_starter),
                    ("home", "away", home_team, away_team, away_starter),
                ]:
                    # Process batters
                    for player_id, player in (
                        boxscore.get("teams", {})
                        .get(team_side, {})
                        .get("players", {})
                        .items()
                    ):
                        # Skip players without batting stats
                        if not player.get("stats", {}).get("batting"):
                            continue

                        actual_player_id = player_id.replace("ID", "")
                        player_name = player.get("person", {}).get("fullName")

                        # Get season stats up to this game
                        season_stats = api.get_player_stats(
                            actual_player_id, season, game_date
                        )

                        # Get matchup stats if opponent starter is available
                        matchup_stats = None
                        if opponent_starter:
                            opponent_pitcher_id = opponent_starter.get(
                                "person", {}
                            ).get("id")
                            try:
                                matchup_stats = api.get_matchup_stats(
                                    actual_player_id, opponent_pitcher_id, season
                                )
                            except Exception as e:
                                logger.error(f"Error getting matchup stats: {e}")

                        # Add to batter stats
                        batter_stats.append(
                            {
                                "game_pk": game_pk,
                                "game_date": game_date,
                                "player_id": actual_player_id,
                                "player_name": player_name,
                                "team_id": team_info["id"],
                                "team_name": team_info["name"],
                                "position": player.get("position", {}).get(
                                    "abbreviation"
                                ),
                                "opposing_team_id": opponent_info["id"],
                                "opposing_team_name": opponent_info["name"],
                                "opposing_pitcher_id": opponent_starter.get(
                                    "person", {}
                                ).get("id")
                                if opponent_starter
                                else None,
                                "opposing_pitcher_name": opponent_starter.get(
                                    "person", {}
                                ).get("fullName")
                                if opponent_starter
                                else None,
                                "game_stats": player.get("stats", {}).get(
                                    "batting", {}
                                ),
                                "season_stats": season_stats,
                                "matchup_stats": matchup_stats,
                            }
                        )

                # Process pitchers for both teams
                for team_side, team_info, opponent_info in [
                    ("away", away_team, home_team),
                    ("home", home_team, away_team),
                ]:
                    for player_id, player in (
                        boxscore.get("teams", {})
                        .get(team_side, {})
                        .get("players", {})
                        .items()
                    ):
                        # Skip players without pitching stats
                        if not player.get("stats", {}).get("pitching"):
                            continue

                        actual_player_id = player_id.replace("ID", "")
                        player_name = player.get("person", {}).get("fullName")

                        # Get season stats up to this game
                        season_stats = api.get_player_stats(
                            actual_player_id, season, game_date
                        )

                        # Add to pitcher stats
                        pitcher_stats.append(
                            {
                                "game_pk": game_pk,
                                "game_date": game_date,
                                "player_id": actual_player_id,
                                "player_name": player_name,
                                "team_id": team_info["id"],
                                "team_name": team_info["name"],
                                "opposing_team_id": opponent_info["id"],
                                "opposing_team_name": opponent_info["name"],
                                "game_stats": player.get("stats", {}).get(
                                    "pitching", {}
                                ),
                                "season_stats": season_stats,
                            }
                        )

                # Add game information
                games_data.append(
                    {
                        "game_pk": game_pk,
                        "game_date": game_date,
                        "away_team_id": away_team["id"],
                        "away_team_name": away_team["name"],
                        "home_team_id": home_team["id"],
                        "home_team_name": home_team["name"],
                        "venue": game.get("venue", {}).get("name"),
                        "status": game["status"]["detailedState"],
                        "weather": weather,
                    }
                )

            except Exception as e:
                logger.error(f"Error processing game {game_pk}: {e}")

    # Convert to DataFrames
    games_df = pd.DataFrame(games_data)
    batter_df = pd.DataFrame(batter_stats)
    pitcher_df = pd.DataFrame(pitcher_stats)
    weather_df = pd.DataFrame(weather_data)

    # Save to CSV
    games_df.to_csv(f"{output_dir}/games.csv", index=False)
    batter_df.to_csv(f"{output_dir}/batters.csv", index=False)
    pitcher_df.to_csv(f"{output_dir}/pitchers.csv", index=False)
    weather_df.to_csv(f"{output_dir}/weather.csv", index=False)

    logger.info(f"Saved data to {output_dir}")
    logger.info(f"Collected {len(games_df)} games")
    logger.info(f"Collected {len(batter_df)} batter performances")
    logger.info(f"Collected {len(pitcher_df)} pitcher performances")

    return {
        "games": games_df,
        "batters": batter_df,
        "pitchers": pitcher_df,
        "weather": weather_df,
    }


# Example usage
if __name__ == "__main__":
    start_date = "2024-03-28"  # Opening Day 2024
    end_date = datetime.now().strftime("%Y-%m-%d")  # Today's date
    output_dir = f"mlb_data_{datetime.now().strftime('%Y%m%d')}"

    data = collect_mlb_data(start_date, end_date, output_dir)

# %%
# Process player photos

player_id = 596019  # Example: Mike Trout
url = f"https://statsapi.mlb.com/api/v1/people/{player_id}?hydrate=person,playerPhotos"
response = requests.get(url)
player_data = response.json()

# Access photos from the response
if "people" in player_data and player_data["people"]:
    player = player_data["people"][0]
    if "photos" in player:
        photos = player["photos"]
        # Process photos here

# %%
if "photos" in player:
    print("true")
else:
    print("false")
# Out:
# false

# %%
BASE_URL = "https://statsapi.mlb.com/api"

endpoint = "v1/schedule"
params = {
    "startDate": "2025-04-04",
    "endDate": "2025-05-04",
    "sportId": 1,  # MLB
    "gameType": "R",  # Regular season games
    "hydrate": "venue,team",
}

url = f"{BASE_URL}/{endpoint}"

response = requests.get(url, params=params)

[
    {
        "game_date": dates["date"],
        "games":[
            (
                {
                "game_pk": games["gamePk"],
                }
            )
        for games in dates.get("games", [])
        ]
    }
    for dates in response.json().get("dates", [])
]
# Out:
# [{'game_date': '2025-04-04',
#   'games': [{'game_pk': 778458},
#    {'game_pk': 778463},
#    {'game_pk': 778460},
#    {'game_pk': 778465},
#    {'game_pk': 778456},
#    {'game_pk': 778461},
#    {'game_pk': 778444},
#    {'game_pk': 778457},
#    {'game_pk': 778459},
#    {'game_pk': 778464},
#    {'game_pk': 778455},
#    {'game_pk': 778454},
#    {'game_pk': 778453},
#    {'game_pk': 778447}]},
#  {'game_date': '2025-04-05',
#   'games': [{'game_pk': 778445},
#    {'game_pk': 778440},
#    {'game_pk': 778450},
#    {'game_pk': 778452},
#    {'game_pk': 778448},
#    {'game_pk': 778449},
#    {'game_pk': 778441},
#    {'game_pk': 778438},
#    {'game_pk': 778446},
#    {'game_pk': 778439},
#    {'game_pk': 778451},
#    {'game_pk': 778442},
#    {'game_pk': 778436},
#    {'game_pk': 778437},
#    {'game_pk': 778443}]},
#  {'game_date': '2025-04-06',
#   'games': [{'game_pk': 778429},
#    {'game_pk': 778443},
#    {'game_pk': 778432},
#    {'game_pk': 778434},
#    {'game_pk': 778428},
#    {'game_pk': 778435},
#    {'game_pk': 778433},
#    {'game_pk': 778422},
#    {'game_pk': 778419},
#    {'game_pk': 778421},
#    {'game_pk': 778430},
#    {'game_pk': 778420},
#    {'game_pk': 778423},
#    {'game_pk': 778427},
#    {'game_pk': 778425},
#    {'game_pk': 778431}]},
#  {'game_date': '2025-04-07',
#   'games': [{'game_pk': 778424},
#    {'game_pk': 778415},
#    {'game_pk': 778418},
#    {'game_pk': 778426},
#    {'game_pk': 778416},
#    {'game_pk': 778411},
#    {'game_pk': 778412},
#    {'game_pk': 778413},
#    {'game_pk': 778405},
#    {'game_pk': 778410},
#    {'game_pk': 778414}]},
#  {'game_date': '2025-04-08',
#   'games': [{'game_pk': 778403},
#    {'game_pk': 778402},
#    {'game_pk': 778407},
#    {'game_pk': 778408},
#    {'game_pk': 778409},
#    {'game_pk': 778404},
#    {'game_pk': 778417},
#    {'game_pk': 778406},
#    {'game_pk': 778401},
#    {'game_pk': 778400},
#    {'game_pk': 778394},
#    {'game_pk': 778396},
#    {'game_pk': 778398},
#    {'game_pk': 778397},
#    {'game_pk': 778395}]},
#  {'game_date': '2025-04-09',
#   'games': [{'game_pk': 778389},
#    {'game_pk': 778390},
#    {'game_pk': 778387},
#    {'game_pk': 778385},
#    {'game_pk': 778381},
#    {'game_pk': 778380},
#    {'game_pk': 778376},
#    {'game_pk': 778392},
#    {'game_pk': 778383},
#    {'game_pk': 778391},
#    {'game_pk': 778386},
#    {'game_pk': 778399},
#    {'game_pk': 778393},
#    {'game_pk': 778388},
#    {'game_pk': 778379}]},
#  {'game_date': '2025-04-10',
#   'games': [{'game_pk': 778382},
#    {'game_pk': 778378},
#    {'game_pk': 778373},
#    {'game_pk': 778371},
#    {'game_pk': 778377},
#    {'game_pk': 778384}]},
#  {'game_date': '2025-04-11',
#   'games': [{'game_pk': 778375},
#    {'game_pk': 778374},
#    {'game_pk': 778367},
#    {'game_pk': 778370},
#    {'game_pk': 778369},
#    {'game_pk': 778366},
#    {'game_pk': 778368},
#    {'game_pk': 778363},
#    {'game_pk': 778365},
#    {'game_pk': 778361},
#    {'game_pk': 778360},
#    {'game_pk': 778364},
#    {'game_pk': 778358},
#    {'game_pk': 778356},
#    {'game_pk': 778372}]},
#  {'game_date': '2025-04-12',
#   'games': [{'game_pk': 778348},
#    {'game_pk': 778347},
#    {'game_pk': 778355},
#    {'game_pk': 778346},
#    {'game_pk': 778362},
#    {'game_pk': 778353},
#    {'game_pk': 778349},
#    {'game_pk': 778354},
#    {'game_pk': 778359},
#    {'game_pk': 778357},
#    {'game_pk': 778351},
#    {'game_pk': 778350},
#    {'game_pk': 778352},
#    {'game_pk': 778345},
#    {'game_pk': 778341}]},
#  {'game_date': '2025-04-13',
#   'games': [{'game_pk': 778344},
#    {'game_pk': 778339},
#    {'game_pk': 778342},
#    {'game_pk': 778343},
#    {'game_pk': 778340},
#    {'game_pk': 778337},
#    {'game_pk': 778329},
#    {'game_pk': 778335},
#    {'game_pk': 778338},
#    {'game_pk': 778336},
#    {'game_pk': 778333},
#    {'game_pk': 778330},
#    {'game_pk': 778334},
#    {'game_pk': 778332},
#    {'game_pk': 778331}]},
#  {'game_date': '2025-04-14',
#   'games': [{'game_pk': 778321},
#    {'game_pk': 778320},
#    {'game_pk': 778328},
#    {'game_pk': 778327},
#    {'game_pk': 778322},
#    {'game_pk': 778324},
#    {'game_pk': 778323},
#    {'game_pk': 778325},
#    {'game_pk': 778315},
#    {'game_pk': 778326}]},
#  {'game_date': '2025-04-15',
#   'games': [{'game_pk': 778314},
#    {'game_pk': 778316},
#    {'game_pk': 778318},
#    {'game_pk': 778313},
#    {'game_pk': 778317},
#    {'game_pk': 778319},
#    {'game_pk': 778312},
#    {'game_pk': 778311},
#    {'game_pk': 778307},
#    {'game_pk': 778309},
#    {'game_pk': 778310},
#    {'game_pk': 778308},
#    {'game_pk': 778306},
#    {'game_pk': 778305},
#    {'game_pk': 778302}]},
#  {'game_date': '2025-04-16',
#   'games': [{'game_pk': 778297},
#    {'game_pk': 778299},
#    {'game_pk': 778295},
#    {'game_pk': 778290},
#    {'game_pk': 778288},
#    {'game_pk': 778301},
#    {'game_pk': 778293},
#    {'game_pk': 778304},
#    {'game_pk': 778303},
#    {'game_pk': 778296},
#    {'game_pk': 778298},
#    {'game_pk': 778300},
#    {'game_pk': 778294},
#    {'game_pk': 778289},
#    {'game_pk': 778287}]},
#  {'game_date': '2025-04-17',
#   'games': [{'game_pk': 778291},
#    {'game_pk': 778280},
#    {'game_pk': 778285},
#    {'game_pk': 778283},
#    {'game_pk': 778279},
#    {'game_pk': 778292},
#    {'game_pk': 778286},
#    {'game_pk': 778282},
#    {'game_pk': 778278},
#    {'game_pk': 778281}]},
#  {'game_date': '2025-04-18',
#   'games': [{'game_pk': 778268},
#    {'game_pk': 778277},
#    {'game_pk': 778271},
#    {'game_pk': 778274},
#    {'game_pk': 778276},
#    {'game_pk': 778272},
#    {'game_pk': 778273},
#    {'game_pk': 778270},
#    {'game_pk': 778275},
#    {'game_pk': 778284},
#    {'game_pk': 778263},
#    {'game_pk': 778269},
#    {'game_pk': 778261},
#    {'game_pk': 778260},
#    {'game_pk': 778266}]},
#  {'game_date': '2025-04-19',
#   'games': [{'game_pk': 778252},
#    {'game_pk': 778265},
#    {'game_pk': 778257},
#    {'game_pk': 778258},
#    {'game_pk': 778262},
#    {'game_pk': 778254},
#    {'game_pk': 778256},
#    {'game_pk': 778251},
#    {'game_pk': 778247},
#    {'game_pk': 778264},
#    {'game_pk': 778255},
#    {'game_pk': 778259},
#    {'game_pk': 778253},
#    {'game_pk': 778267},
#    {'game_pk': 778243}]},
#  {'game_date': '2025-04-20',
#   'games': [{'game_pk': 778250},
#    {'game_pk': 778242},
#    {'game_pk': 778249},
#    {'game_pk': 778245},
#    {'game_pk': 778248},
#    {'game_pk': 778241},
#    {'game_pk': 778246},
#    {'game_pk': 778244},
#    {'game_pk': 778240},
#    {'game_pk': 778239},
#    {'game_pk': 778236},
#    {'game_pk': 778234},
#    {'game_pk': 778235},
#    {'game_pk': 778266},
#    {'game_pk': 778232},
#    {'game_pk': 778237}]},
#  {'game_date': '2025-04-21',
#   'games': [{'game_pk': 778238},
#    {'game_pk': 778227},
#    {'game_pk': 778228},
#    {'game_pk': 778230},
#    {'game_pk': 778225},
#    {'game_pk': 778233},
#    {'game_pk': 778231},
#    {'game_pk': 778226}]},
#  {'game_date': '2025-04-22',
#   'games': [{'game_pk': 778218},
#    {'game_pk': 778221},
#    {'game_pk': 778219},
#    {'game_pk': 778222},
#    {'game_pk': 778224},
#    {'game_pk': 778223},
#    {'game_pk': 778229},
#    {'game_pk': 778215},
#    {'game_pk': 778220},
#    {'game_pk': 778216},
#    {'game_pk': 778217},
#    {'game_pk': 778211},
#    {'game_pk': 778212},
#    {'game_pk': 778210},
#    {'game_pk': 778213}]},
#  {'game_date': '2025-04-23',
#   'games': [{'game_pk': 778214},
#    {'game_pk': 778209},
#    {'game_pk': 778203},
#    {'game_pk': 778208},
#    {'game_pk': 778206},
#    {'game_pk': 778204},
#    {'game_pk': 778207},
#    {'game_pk': 778205},
#    {'game_pk': 778200},
#    {'game_pk': 778201},
#    {'game_pk': 778202},
#    {'game_pk': 778199},
#    {'game_pk': 778198},
#    {'game_pk': 778197},
#    {'game_pk': 778195}]},
#  {'game_date': '2025-04-24',
#   'games': [{'game_pk': 778189},
#    {'game_pk': 778196},
#    {'game_pk': 778190},
#    {'game_pk': 778195},
#    {'game_pk': 778194},
#    {'game_pk': 778193},
#    {'game_pk': 778191},
#    {'game_pk': 778188},
#    {'game_pk': 778192}]},
#  {'game_date': '2025-04-25',
#   'games': [{'game_pk': 778182},
#    {'game_pk': 778183},
#    {'game_pk': 778185},
#    {'game_pk': 778187},
#    {'game_pk': 778186},
#    {'game_pk': 778184},
#    {'game_pk': 778181},
#    {'game_pk': 778172},
#    {'game_pk': 778177},
#    {'game_pk': 778175},
#    {'game_pk': 778178},
#    {'game_pk': 778176},
#    {'game_pk': 778171},
#    {'game_pk': 778180},
#    {'game_pk': 778179}]},
#  {'game_date': '2025-04-26',
#   'games': [{'game_pk': 778179},
#    {'game_pk': 778169},
#    {'game_pk': 778168},
#    {'game_pk': 778180},
#    {'game_pk': 778166},
#    {'game_pk': 778164},
#    {'game_pk': 778161},
#    {'game_pk': 778173},
#    {'game_pk': 778159},
#    {'game_pk': 778174},
#    {'game_pk': 778165},
#    {'game_pk': 778167},
#    {'game_pk': 778162},
#    {'game_pk': 778160},
#    {'game_pk': 778163},
#    {'game_pk': 778154},
#    {'game_pk': 778170}]},
#  {'game_date': '2025-04-27',
#   'games': [{'game_pk': 778153},
#    {'game_pk': 778156},
#    {'game_pk': 778170},
#    {'game_pk': 778157},
#    {'game_pk': 778155},
#    {'game_pk': 778144},
#    {'game_pk': 778152},
#    {'game_pk': 778150},
#    {'game_pk': 778148},
#    {'game_pk': 778151},
#    {'game_pk': 778149},
#    {'game_pk': 778145},
#    {'game_pk': 778146},
#    {'game_pk': 778147},
#    {'game_pk': 778136},
#    {'game_pk': 778158}]},
#  {'game_date': '2025-04-28',
#   'games': [{'game_pk': 778138},
#    {'game_pk': 778139},
#    {'game_pk': 778140},
#    {'game_pk': 778141},
#    {'game_pk': 778143},
#    {'game_pk': 778142},
#    {'game_pk': 778137},
#    {'game_pk': 778132}]},
#  {'game_date': '2025-04-29',
#   'games': [{'game_pk': 778129},
#    {'game_pk': 778133},
#    {'game_pk': 778135},
#    {'game_pk': 778131},
#    {'game_pk': 778128},
#    {'game_pk': 778127},
#    {'game_pk': 778130},
#    {'game_pk': 778125},
#    {'game_pk': 778122},
#    {'game_pk': 778124},
#    {'game_pk': 778120},
#    {'game_pk': 778121},
#    {'game_pk': 778126},
#    {'game_pk': 778123},
#    {'game_pk': 778134}]},
#  {'game_date': '2025-04-30',
#   'games': [{'game_pk': 778134},
#    {'game_pk': 778119},
#    {'game_pk': 778110},
#    {'game_pk': 778102},
#    {'game_pk': 778109},
#    {'game_pk': 778104},
#    {'game_pk': 778105},
#    {'game_pk': 778116},
#    {'game_pk': 778115},
#    {'game_pk': 778112},
#    {'game_pk': 778118},
#    {'game_pk': 778113},
#    {'game_pk': 778114},
#    {'game_pk': 778117},
#    {'game_pk': 778111},
#    {'game_pk': 778106}]},
#  {'game_date': '2025-05-01',
#   'games': [{'game_pk': 778100},
#    {'game_pk': 778107},
#    {'game_pk': 778103},
#    {'game_pk': 778097},
#    {'game_pk': 778108},
#    {'game_pk': 778094},
#    {'game_pk': 778096},
#    {'game_pk': 778099},
#    {'game_pk': 778095},
#    {'game_pk': 778101},
#    {'game_pk': 778098}]},
#  {'game_date': '2025-05-02',
#   'games': [{'game_pk': 778087},
#    {'game_pk': 778090},
#    {'game_pk': 778086},
#    {'game_pk': 778093},
#    {'game_pk': 778088},
#    {'game_pk': 778081},
#    {'game_pk': 778089},
#    {'game_pk': 778091},
#    {'game_pk': 778092},
#    {'game_pk': 778079},
#    {'game_pk': 778083},
#    {'game_pk': 778080},
#    {'game_pk': 778084},
#    {'game_pk': 778085},
#    {'game_pk': 778082}]},
#  {'game_date': '2025-05-03',
#   'games': [{'game_pk': 778074},
#    {'game_pk': 778066},
#    {'game_pk': 778064},
#    {'game_pk': 778065},
#    {'game_pk': 778069},
#    {'game_pk': 778073},
#    {'game_pk': 778075},
#    {'game_pk': 778078},
#    {'game_pk': 778077},
#    {'game_pk': 778070},
#    {'game_pk': 778071},
#    {'game_pk': 778072},
#    {'game_pk': 778076},
#    {'game_pk': 778067},
#    {'game_pk': 778068}]},
#  {'game_date': '2025-05-04',
#   'games': [{'game_pk': 778053},
#    {'game_pk': 778068},
#    {'game_pk': 778062},
#    {'game_pk': 778051},
#    {'game_pk': 778063},
#    {'game_pk': 778057},
#    {'game_pk': 778056},
#    {'game_pk': 778061},
#    {'game_pk': 778059},
#    {'game_pk': 778055},
#    {'game_pk': 778054},
#    {'game_pk': 778052},
#    {'game_pk': 778048},
#    {'game_pk': 778050},
#    {'game_pk': 778058},
#    {'game_pk': 778060}]}]

# %%
endpoint = f"v1.1/game/778053/feed/live"
params = {"hydrate": "boxscore,weather"}

url = f"{BASE_URL}/{endpoint}"

response = requests.get(url, params=params)


for player_id, player in (
    response.json().get("liveData", {}).get("boxscore", {}).get("teams", {}).get("away", {}).get("players", {}).items()
    ):
    if not response.json().get("liveData", {}).get("boxscore", {}).get("teams", {}).get(
    "away", {}
).get("players", {})[player_id].get("stats", {}).get("batting", {}):
        continue
    elif (
        response.json()
        .get("liveData", {})
        .get("boxscore", {})
        .get("teams", {})
        .get("away", {})
        .get("players", {})[player_id]
        .get("stats", {})
        .get("batting", {})
        .get("hits") > 0
    ):
        print(player_id)
    else:
        continue
# Out:
# ID621438
# ID668901
# ID682668
# ID624413
# ID596019
# ID607043
# ID665742

# %%
response.json().get("liveData", {}).get("boxscore", {}).get("teams", {}).get(
    "away", {}
).get("players", {})["ID596019"].get("stats", {}).get("batting", {})
# Out:
# {'summary': '1-5 | 2 K, 3 RBI',
#  'gamesPlayed': 1,
#  'flyOuts': 0,
#  'groundOuts': 2,
#  'airOuts': 0,
#  'runs': 0,
#  'doubles': 0,
#  'triples': 0,
#  'homeRuns': 0,
#  'strikeOuts': 2,
#  'baseOnBalls': 0,
#  'intentionalWalks': 0,
#  'hits': 1,
#  'hitByPitch': 0,
#  'atBats': 5,
#  'caughtStealing': 0,
#  'stolenBases': 0,
#  'stolenBasePercentage': '.---',
#  'groundIntoDoublePlay': 0,
#  'groundIntoTriplePlay': 0,
#  'plateAppearances': 5,
#  'totalBases': 1,
#  'rbi': 3,
#  'leftOnBase': 3,
#  'sacBunts': 0,
#  'sacFlies': 0,
#  'catchersInterference': 0,
#  'pickoffs': 0,
#  'atBatsPerHomeRun': '-.--',
#  'popOuts': 0,
#  'lineOuts': 0}
